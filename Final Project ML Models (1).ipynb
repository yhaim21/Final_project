# %%
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# # Determining Baseline R^2 using just Average FPTS

# %%
scraped_df = pd.read_csv('ma10.csv')

x_baseline = scraped_df['FPTS10_MA'].values.reshape(-1, 1)
y_baseline = scraped_df['FPTS']

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

from sklearn.model_selection import cross_val_score
scores = cross_val_score(reg, x_baseline, y_baseline, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.43602285 0.49512975 0.4811836  0.47346451]
# 0.4714501782590032

# %%
from sklearn.linear_model import Lasso

Lasso = Lasso()

scores = cross_val_score(Lasso, x_baseline, y_baseline, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.43625473 0.49490616 0.48086367 0.47358931]
# 0.47140346695423874

# %%
from sklearn.ensemble import RandomForestRegressor

for i in [3, 4, 5, 6]:
    ran_forrest = RandomForestRegressor(max_depth=i)
    scores = cross_val_score(ran_forrest, x_baseline, y_baseline, cv=4)
    print("Scores depth", i, ':', scores)
    avg_R_squared = scores.mean()
    print(avg_R_squared)
# Out:
# Scores depth 3 : [0.43357477 0.4821246  0.47605663 0.47177748]
# 0.4658833707573993
# Scores depth 4 : [0.43550677 0.48797159 0.4789567  0.47321043]
# 0.46891137311768377
# Scores depth 5 : [0.43413723 0.48459026 0.47927173 0.4709623 ]
# 0.46724037996323753
# Scores depth 6 : [0.43409731 0.48465491 0.4786028  0.47074481]
# 0.46702495939879324

# %% [markdown]
# From these baseline models, we can see that the best out of sample R^2 using just previous FPTS to predict future FPTS is about .4714. We will try to construct models that perform better than this.

# %% [markdown]
# # Training the model for top 50 players

# %% [markdown]
# ## Training a Linear Regression Model

# %% [markdown]
# ### Splitting the data into X and y
# #### Don't need train and test sets because using cross validation

# %%
# Import data to train the model

scraped_df = pd.read_csv('ma10.csv')

X = scraped_df.loc[:,['FPTS10_MA', 'PTS10_MA', 'AST10_MA', 'STL10_MA', 'BLK10_MA', 'DD10_MA', 'DT10_MA', 'MP10_MA', 'FGA10_MA', 'D_R']]
y = scraped_df['FPTS']

X
# Out:
#        FPTS10_MA  PTS10_MA  AST10_MA  STL10_MA  BLK10_MA  DD10_MA  DT10_MA  \
# 0         44.450      22.5       6.2       1.8       0.4     0.30      0.2
# 1         45.925      22.8       6.7       2.0       0.3     0.30      0.2
# 2         44.825      23.9       5.7       1.9       0.4     0.30      0.1
# 3         41.800      21.4       5.7       1.8       0.5     0.35      0.1
# 4         39.575      20.0       5.3       1.9       0.4     0.30      0.0
# ...          ...       ...       ...       ...       ...      ...      ...
# 10232     27.175      13.2       4.2       1.0       0.2     0.15      0.0
# 10233     25.725      12.2       4.0       1.0       0.2     0.15      0.0
# 10234     25.500      11.9       3.9       1.0       0.3     0.20      0.0
# 10235     26.350      11.9       4.4       1.1       0.3     0.20      0.0
# 10236     26.475      12.4       4.4       1.1       0.3     0.20      0.0
#
#        MP10_MA  FGA10_MA    D_R
# 0       36.330      15.0  109.2
# 1       36.256      14.5  109.2
# 2       35.692      14.7  112.6
# 3       35.322      14.0  108.1
# 4       35.113      13.2  112.6
# ...        ...       ...    ...
# 10232   31.235      10.1  116.0
# 10233   30.764       9.5  116.0
# 10234   31.298       9.3  111.7
# 10235   31.474       9.7  111.7
# 10236   31.964       9.7  111.4
#
# [10237 rows x 10 columns]

# %% [markdown]
# ### fitting the linear model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso


reg = LinearRegression()
Lasso = Lasso()

# %% [markdown]
# ### Cacluating R^2 with 4-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(reg, X, y, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.44382352 0.49727393 0.48626308 0.48222697]
# 0.47739687672774067

# %% [markdown]
# ### Testing LASSO

# %%
scores = cross_val_score(Lasso, X, y, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.43830434 0.49534387 0.48272585 0.47575517]
# 0.4730323093327961

# %% [markdown]
# ## Training a Random Forrest Model

# %%
from sklearn.ensemble import RandomForestRegressor

for i in [3, 4, 5, 6]:
    ran_forrest = RandomForestRegressor(max_depth=i)
    scores = cross_val_score(ran_forrest, X, y, cv=4)
    print("Scores depth", i, ':', scores)
    avg_R_squared = scores.mean()
    print(avg_R_squared)
# Out:
# Scores depth 3 : [0.4330808  0.48237737 0.4749067  0.4717473 ]
# 0.4655280427984382
# Scores depth 4 : [0.43519636 0.48277316 0.4792083  0.47347034]
# 0.46766203989362776
# Scores depth 5 : [0.43529714 0.48418646 0.48058157 0.47357956]
# 0.46841118411098415
# Scores depth 6 : [0.43493847 0.48285863 0.47855741 0.47198297]
# 0.46708437010694703

# %% [markdown]
# Based on 4-Fold Cross Validation, a simple linear model does the best job at predicting out-of-sample FPTS. Therefore, we will use this model to predict the FPTS of the top 50 fantasy players each day.

# %%
Top_50_Model = LinearRegression().fit(X, y)

# %% [markdown]
# # Training the model for the rest of the players

# %% [markdown]
# We are unable to scrape detailed data every day for players below the top 50 fantasy performers. Therefore, we will evaluate the effectiveness of a second model that only uses the two features available for all players: Average FPTS and D_R

# %%
X_simple = scraped_df.loc[:,['FPTS10_MA', 'D_R']]
y_simple = scraped_df['FPTS']

# %%
scores = cross_val_score(reg, X_simple, y_simple, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.43906753 0.49400228 0.48447102 0.47638676]
# 0.473481897495585

# %%
scores = cross_val_score(Lasso, X_simple, y_simple, cv=4)
avg_R_squared = scores.mean()
print(scores)
avg_R_squared
# Out:
# [0.43823821 0.49515513 0.48287207 0.47550573]
# 0.47294278473675555

# %%
for i in [3, 4, 5, 6]:
    ran_forrest = RandomForestRegressor(max_depth=i)
    scores = cross_val_score(ran_forrest, X_simple, y_simple, cv=4)
    print("Scores depth", i, ':', scores)
    avg_R_squared = scores.mean()
    print(avg_R_squared)
# Out:
# Scores depth 3 : [0.43281577 0.48228516 0.47596782 0.47241594]
# 0.4658711713385235
# Scores depth 4 : [0.43610661 0.4837773  0.48087601 0.47440807]
# 0.46879199595869087
# Scores depth 5 : [0.43399275 0.48350321 0.4814746  0.47374867]
# 0.4681798090179746
# Scores depth 6 : [0.42689153 0.48170734 0.47968864 0.46986556]
# 0.46453826649764074

# %% [markdown]
# Once again, a simple linear regression was the strongest model for predicting out of sample in our simplified set of features. Therefore, we will again use this model for predicting the FPTS of the rest of players outside of the top 50.

# %%
Rest_of_Players_Model = LinearRegression().fit(X_simple, y_simple)

# %% [markdown]
# # Using the Models to Predict Performance

# %% [markdown]
# ### Upload the data for eligible players from DraftKings.com

# %%
DK_Data = pd.read_csv('Final Project\DKSalaries.csv')
DK_Data['Game Info'].astype('string')
# Out:
# 0      WAS@UTA 04/12/2021 09:00PM ET
# 1      PHI@DAL 04/12/2021 07:30PM ET
# 2      BKN@MIN 04/12/2021 08:00PM ET
# 3      BKN@MIN 04/12/2021 08:00PM ET
# 4       DEN@GS 04/12/2021 10:00PM ET
#                    ...
# 292    BKN@MIN 04/12/2021 08:00PM ET
# 293    BKN@MIN 04/12/2021 08:00PM ET
# 294    BKN@MIN 04/12/2021 08:00PM ET
# 295    BKN@MIN 04/12/2021 08:00PM ET
# 296    BKN@MIN 04/12/2021 08:00PM ET
# Name: Game Info, Length: 297, dtype: string

# %%
DK_Data
# Out:
#     Position                      Name + ID                Name        ID  \
# 0         PG   Russell Westbrook (17028427)   Russell Westbrook  17028427
# 1      PG/SF         Luka Doncic (17028430)         Luka Doncic  17028430
# 2         PG        James Harden (17028435)        James Harden  17028435
# 3          C  Karl-Anthony Towns (17028438)  Karl-Anthony Towns  17028438
# 4          C        Nikola Jokic (17028440)        Nikola Jokic  17028440
# ..       ...                            ...                 ...       ...
# 292        C            Ed Davis (17029202)            Ed Davis  17029202
# 293     PF/C   Jarred Vanderbilt (17029204)   Jarred Vanderbilt  17029204
# 294       SG   Spencer Dinwiddie (17029324)   Spencer Dinwiddie  17029324
# 295       PG       Chris Chiozza (17029327)       Chris Chiozza  17029327
# 296       PF        Reggie Perry (17029330)        Reggie Perry  17029330
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 0         PG/G/UTIL   11000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 1    PG/SF/F/G/UTIL   10700  PHI@DAL 04/12/2021 07:30PM ET        DAL
# 2         PG/G/UTIL   10600  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 3            C/UTIL   10500  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 4            C/UTIL   10400   DEN@GS 04/12/2021 10:00PM ET        DEN
# ..              ...     ...                            ...        ...
# 292          C/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 293     PF/C/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 294       SG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 295       PG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 296       PF/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
#
#      AvgPointsPerGame
# 0               55.26
# 1               55.18
# 2               56.62
# 3               50.92
# 4               58.43
# ..                ...
# 292             12.09
# 293             16.41
# 294             18.08
# 295             10.74
# 296             10.46
#
# [297 rows x 9 columns]

# %% [markdown]
# ## Adding Opponent Defensive Rating data from another dataset

# %% [markdown]
# Extract the Opponent from the Game Info string by comparing it to the player's team in TeamAbbrev

# %%
# Create new Away and Home columns

DK_Data['Away'] = DK_Data['Game Info'].str.split('@').str[0]
DK_Data['Home'] = DK_Data['Game Info'].str.split('@').str[1].str[:3]
DK_Data
# Out:
#     Position                      Name + ID                Name        ID  \
# 0         PG   Russell Westbrook (17028427)   Russell Westbrook  17028427
# 1      PG/SF         Luka Doncic (17028430)         Luka Doncic  17028430
# 2         PG        James Harden (17028435)        James Harden  17028435
# 3          C  Karl-Anthony Towns (17028438)  Karl-Anthony Towns  17028438
# 4          C        Nikola Jokic (17028440)        Nikola Jokic  17028440
# ..       ...                            ...                 ...       ...
# 292        C            Ed Davis (17029202)            Ed Davis  17029202
# 293     PF/C   Jarred Vanderbilt (17029204)   Jarred Vanderbilt  17029204
# 294       SG   Spencer Dinwiddie (17029324)   Spencer Dinwiddie  17029324
# 295       PG       Chris Chiozza (17029327)       Chris Chiozza  17029327
# 296       PF        Reggie Perry (17029330)        Reggie Perry  17029330
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 0         PG/G/UTIL   11000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 1    PG/SF/F/G/UTIL   10700  PHI@DAL 04/12/2021 07:30PM ET        DAL
# 2         PG/G/UTIL   10600  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 3            C/UTIL   10500  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 4            C/UTIL   10400   DEN@GS 04/12/2021 10:00PM ET        DEN
# ..              ...     ...                            ...        ...
# 292          C/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 293     PF/C/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 294       SG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 295       PG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 296       PF/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
#
#      AvgPointsPerGame Away Home
# 0               55.26  WAS  UTA
# 1               55.18  PHI  DAL
# 2               56.62  BKN  MIN
# 3               50.92  BKN  MIN
# 4               58.43  DEN  GS
# ..                ...  ...  ...
# 292             12.09  BKN  MIN
# 293             16.41  BKN  MIN
# 294             18.08  BKN  MIN
# 295             10.74  BKN  MIN
# 296             10.46  BKN  MIN
#
# [297 rows x 11 columns]

# %%
# Use boolean masks to determine the Opponent

mask = DK_Data['Away'] == DK_Data['TeamAbbrev']
mask2 = DK_Data['Home'] == DK_Data['TeamAbbrev']
DK_Data['OPP'] = mask*DK_Data['Home'] + mask2*DK_Data['Away']
DK_Data
# Out:
#     Position                      Name + ID                Name        ID  \
# 0         PG   Russell Westbrook (17028427)   Russell Westbrook  17028427
# 1      PG/SF         Luka Doncic (17028430)         Luka Doncic  17028430
# 2         PG        James Harden (17028435)        James Harden  17028435
# 3          C  Karl-Anthony Towns (17028438)  Karl-Anthony Towns  17028438
# 4          C        Nikola Jokic (17028440)        Nikola Jokic  17028440
# ..       ...                            ...                 ...       ...
# 292        C            Ed Davis (17029202)            Ed Davis  17029202
# 293     PF/C   Jarred Vanderbilt (17029204)   Jarred Vanderbilt  17029204
# 294       SG   Spencer Dinwiddie (17029324)   Spencer Dinwiddie  17029324
# 295       PG       Chris Chiozza (17029327)       Chris Chiozza  17029327
# 296       PF        Reggie Perry (17029330)        Reggie Perry  17029330
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 0         PG/G/UTIL   11000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 1    PG/SF/F/G/UTIL   10700  PHI@DAL 04/12/2021 07:30PM ET        DAL
# 2         PG/G/UTIL   10600  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 3            C/UTIL   10500  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 4            C/UTIL   10400   DEN@GS 04/12/2021 10:00PM ET        DEN
# ..              ...     ...                            ...        ...
# 292          C/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 293     PF/C/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        MIN
# 294       SG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 295       PG/G/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
# 296       PF/F/UTIL    3000  BKN@MIN 04/12/2021 08:00PM ET        BKN
#
#      AvgPointsPerGame Away Home  OPP
# 0               55.26  WAS  UTA  UTA
# 1               55.18  PHI  DAL  PHI
# 2               56.62  BKN  MIN  MIN
# 3               50.92  BKN  MIN  BKN
# 4               58.43  DEN  GS   GS
# ..                ...  ...  ...  ...
# 292             12.09  BKN  MIN  BKN
# 293             16.41  BKN  MIN  BKN
# 294             18.08  BKN  MIN  MIN
# 295             10.74  BKN  MIN  MIN
# 296             10.46  BKN  MIN  MIN
#
# [297 rows x 12 columns]

# %%
# Pull in the data on Defensive Ratings of each team over the past three seasons

D_R_Data = pd.read_csv('Defensive Ratings.csv')
D_R_Data['OPP'] = D_R_Data['Fantasy Data Abbr']
D_R_Data
# Out:
#                  Full Name  Abr Fantasy Data Abbr  2020-2021  2019-2020  \
# 0            Atlanta Hawks  Atl               ATL      112.3      114.4
# 1           Boston Celtics  Bos               BOS      111.4      106.5
# 2            Brooklyn Nets  Bkn               BKN      113.3      109.2
# 3        Charlotte Hornets  Cha               CHA      111.3      112.8
# 4            Chicago Bulls  Chi               CHI      112.3      108.9
# 5      Cleveland Cavaliers  Cle               CLE      112.1      114.8
# 6         Dallas Mavericks  Dal               DAL      111.7      111.2
# 7           Denver Nuggets  Den               DEN      111.7      110.4
# 8          Detroit Pistons  Det               DET      112.4      112.3
# 9    Golden State Warriors  GSW                GS      110.4      113.0
# 10         Houston Rockets  Hou               HOU      112.6      109.8
# 11          Indiana Pacers  Ind               IND      111.4      107.5
# 12             LA Clippers  LAC               LAC      110.9      106.9
# 13      Los Angeles Lakers  LAL               LAL      105.6      106.1
# 14       Memphis Grizzlies  Mem               MEM      110.0      109.7
# 15              Miami Heat  Mia               MIA      109.3      109.3
# 16         Milwaukee Bucks  Mil               MIL      109.9      102.5
# 17  Minnesota Timberwolves  Min               MIN      114.7      111.6
# 18    New Orleans Pelicans  Nor                NO      115.0      111.8
# 19         New York Knicks  NYK                NY      107.4      112.4
# 20   Oklahoma City Thunder  OKC               OKC      112.4      108.1
# 21           Orlando Magic  Orl               ORL      112.7      109.2
# 22      Philadelphia 76ers  Phi               PHI      106.4      108.4
# 23            Phoenix Suns  Pho               PHO      108.6      110.8
# 24  Portland Trail Blazers  Por               POR      116.0      114.3
# 25        Sacramento Kings  Sac               SAC      117.8      111.4
# 26       San Antonio Spurs  SAS                SA      111.0      112.6
# 27         Toronto Raptors  Tor               TOR      111.8      104.7
# 28               Utah Jazz  Uta               UTA      107.6      109.3
# 29      Washington Wizards  Was               WAS      113.3      114.7
#
#     2018-2019  OPP
# 0       113.1  ATL
# 1       107.0  BOS
# 2       109.0  BKN
# 3       112.0  CHA
# 4       112.8  CHI
# 5       116.8  CLE
# 6       110.1  DAL
# 7       108.1  DEN
# 8       108.7  DET
# 9       108.6   GS
# 10      110.1  HOU
# 11      106.0  IND
# 12      110.4  LAC
# 13      108.9  LAL
# 14      108.0  MEM
# 15      107.1  MIA
# 16      104.9  MIL
# 17      112.2  MIN
# 18      112.0   NO
# 19      112.9   NY
# 20      106.5  OKC
# 21      107.6  ORL
# 22      109.0  PHI
# 23      114.2  PHO
# 24      109.5  POR
# 25      110.8  SAC
# 26      110.6   SA
# 27      106.8  TOR
# 28      105.3  UTA
# 29      112.9  WAS

# %%
# Join the Defensive Rating data with the data downloaded from DraftKings based on the OPP column

DK_Data = DK_Data.merge(D_R_Data, left_on='OPP', right_on='OPP')

DK_Data
# Out:
#     Position                     Name + ID               Name        ID  \
# 0         PG  Russell Westbrook (17028427)  Russell Westbrook  17028427
# 1         SG       Bradley Beal (17028476)       Bradley Beal  17028476
# 2         PF      Rui Hachimura (17028596)      Rui Hachimura  17028596
# 3      SF/PF        Deni Avdija (17028719)        Deni Avdija  17028719
# 4          C      Thomas Bryant (17028760)      Thomas Bryant  17028760
# ..       ...                           ...                ...       ...
# 192    SG/SF        Gary Harris (17028917)        Gary Harris  17028917
# 193       PG      Devin Cannady (17028979)      Devin Cannady  17028979
# 194       PG         Karim Mane (17029065)         Karim Mane  17029065
# 195       PF     Jonathan Isaac (17029196)     Jonathan Isaac  17029196
# 196       PG     Markelle Fultz (17029199)     Markelle Fultz  17029199
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 0         PG/G/UTIL   11000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 1         SG/G/UTIL    8900  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 2         PF/F/UTIL    6300  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 3      SF/PF/F/UTIL    5000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# 4            C/UTIL    4600  WAS@UTA 04/12/2021 09:00PM ET        WAS
# ..              ...     ...                            ...        ...
# 192  SG/SF/F/G/UTIL    3900   SA@ORL 04/12/2021 08:00PM ET        ORL
# 193       PG/G/UTIL    3500   SA@ORL 04/12/2021 08:00PM ET        ORL
# 194       PG/G/UTIL    3200   SA@ORL 04/12/2021 08:00PM ET        ORL
# 195       PF/F/UTIL    3000   SA@ORL 04/12/2021 08:00PM ET        ORL
# 196       PG/G/UTIL    3000   SA@ORL 04/12/2021 08:00PM ET        ORL
#
#      AvgPointsPerGame Away Home  OPP          Full Name  Abr  \
# 0               55.26  WAS  UTA  UTA          Utah Jazz  Uta
# 1               46.85  WAS  UTA  UTA          Utah Jazz  Uta
# 2               25.29  WAS  UTA  UTA          Utah Jazz  Uta
# 3               16.47  WAS  UTA  UTA          Utah Jazz  Uta
# 4               26.62  WAS  UTA  UTA          Utah Jazz  Uta
# ..                ...  ...  ...  ...                ...  ...
# 192             17.43   SA  ORL   SA  San Antonio Spurs  SAS
# 193              4.00   SA  ORL   SA  San Antonio Spurs  SAS
# 194              3.94   SA  ORL   SA  San Antonio Spurs  SAS
# 195              0.00   SA  ORL   SA  San Antonio Spurs  SAS
# 196             26.66   SA  ORL   SA  San Antonio Spurs  SAS
#
#     Fantasy Data Abbr  2020-2021  2019-2020  2018-2019
# 0                 UTA      107.6      109.3      105.3
# 1                 UTA      107.6      109.3      105.3
# 2                 UTA      107.6      109.3      105.3
# 3                 UTA      107.6      109.3      105.3
# 4                 UTA      107.6      109.3      105.3
# ..                ...        ...        ...        ...
# 192                SA      111.0      112.6      110.6
# 193                SA      111.0      112.6      110.6
# 194                SA      111.0      112.6      110.6
# 195                SA      111.0      112.6      110.6
# 196                SA      111.0      112.6      110.6
#
# [197 rows x 18 columns]

# %% [markdown]
# ## Use Top 50 Model to predict performance of Top 50 Fantasy Players

# %%
total_player_dictionary = pd.read_csv('player_data_csv.csv')
total_player_dictionary
# Out:
#                   Name  Opp  Season Team  GMS        ST        PTS        REB  \
# 0    Russell Westbrook  Uta    2021  WAS   46  1.000000  21.717391  10.695652
# 1        Stephen Curry  Den    2021   GS   46  1.000000  30.413043   5.543478
# 2      Zion Williamson  Sac    2021   NO   49  1.000000  26.836735   7.142857
# 3       Nikola Vucevic  Mem    2021  CHI   54  1.000000  24.037037  11.388889
# 4         Nikola Jokic  GSW    2021  DEN   54  1.000000  26.166667  10.907407
# 5          Luka Doncic  Phi    2021  DAL   48  1.000000  28.562500   7.979167
# 6         De'Aaron Fox  Nor    2021  SAC   53  1.000000  25.037736   3.433962
# 7         Bradley Beal  Uta    2021  WAS   45  0.977778  30.311111   4.733333
# 8     Donovan Mitchell  Was    2021  UTA   51  1.000000  26.607843   4.450980
# 9          Joel Embiid  Dal    2021  PHI   36  1.000000  29.555556  10.944444
# 10       Julius Randle  LAL    2021   NY   54  1.000000  23.037037  10.666667
# 11      Richaun Holmes  Nor    2021  SAC   50  1.000000  14.120000   8.940000
# 12           John Wall  Pho    2021  HOU   35  1.000000  20.571429   3.285714
# 13         Rudy Gobert  Was    2021  UTA   54  1.000000  14.462963  13.388889
# 14       Tobias Harris  Dal    2021  PHI   48  1.000000  20.354167   7.250000
# 15   Jonas Valanciunas  Chi    2021  MEM   47  0.978723  16.978723  12.702128
# 16        Devin Booker  Hou    2021  PHO   49  1.000000  26.000000   4.183673
# 17      Andrew Wiggins  Den    2021   GS   54  1.000000  18.037037   4.777778
# 18     Dejounte Murray  Orl    2021   SA   50  1.000000  15.880000   6.840000
# 19       DeMar DeRozan  Orl    2021   SA   45  1.000000  21.155556   4.311111
# 44   3.018182  0.254545  ...   63.8   51.2    2.5     3.7     2.4   2.2
# 45   2.205128  0.179487  ...   48.8   32.1    1.6     1.7     2.5   1.1
# 46   3.250000  1.035714  ...   78.0   28.9    3.0     3.9     2.4   1.4
# 47   2.379310  1.103448  ...   36.7    0.0    1.7     5.1     0.0   2.6
# 48   2.318182  0.454545  ...   83.2   23.8    4.3     4.2     1.9   1.5
# 49   5.071429  0.238095  ...   46.7   32.5    0.7     2.7     0.9   1.9
#
#     10MIN  10DD2  10TD3  10FPTS
# 0     NaN     10      9   56.10
# 1     NaN      1      0   47.90
# 2     NaN      2      0   48.24
# 3     NaN      5      0   41.61
# 4     NaN      8      2   48.63
# 5     NaN      0      0   42.10
# 6     NaN      0      0   44.97
# 7     NaN      0      0   31.66
# 8     NaN      0      0   41.64
# 9     NaN      3      0   47.65
# 10    NaN      5      2   41.89
# 11    NaN      5      0   31.59
# 12    NaN      3      1   38.18
# 13    NaN      7      0   37.53
# 14    NaN      1      0   34.04
# 15    NaN     10      0   41.43
# 16    NaN      0      0   40.13
# 17    NaN      1      0   33.80
# 18    NaN      0      0   36.48
# 19    NaN      1      0   37.23
# 20    NaN      1      0   37.08
# 21    NaN      1      0   37.42
# 22    NaN      1      0   32.07
# 23    NaN      3      0   31.88
# 24    NaN      6      0   35.95
# 25    NaN      5      0   34.09
# 26    NaN      1      0   29.37
# 27    NaN      4      0   34.95
# 28    NaN      3      0   28.15
# 29    NaN      1      0   31.19
# 30    NaN      2      0   22.32
# 31    NaN      2      0   30.00
# 32    NaN      0      0   27.72
# 33    NaN      2      0   24.55
# 34    NaN      2      0   27.78
# 35    NaN      5      0   30.82
# 36    NaN      1      0   27.39
# 37    NaN      0      0   37.20
# 38    NaN      7      0   32.91
# 39    NaN      2      0   27.43
# 40    NaN      2      0   29.56
# 41    NaN      0      0   24.12
# 42    NaN      0      0   19.93
# 43    NaN      0      0   26.37
# 44    NaN      0      0   26.21
# 45    NaN      0      0   20.72
# 46    NaN      0      0   29.07
# 47    NaN      4      0   26.97
# 48    NaN      0      0   27.27
# 49    NaN      1      0   21.85
#
# [50 rows x 40 columns]

# %% [markdown]
# ### Manage the data to get it in the right format

# %% [markdown]
# #### Conduct a join to add Opponent Defensive Rating, create new columns that are combinations of current columns

# %%
total_player_dictionary = total_player_dictionary.merge(D_R_Data, left_on='Opp', right_on='Abr')

total_player_dictionary['10_FGM'] = total_player_dictionary['10_2PM'] + total_player_dictionary['10_3PM']

total_player_dictionary['10_FGA'] = total_player_dictionary['10_FGM']/(total_player_dictionary['10FG%']/100)

total_player_dictionary['10DD2'] = total_player_dictionary['10DD2']/10

total_player_dictionary['10TD3'] = total_player_dictionary['10TD3']/10

total_player_dictionary = total_player_dictionary.set_index('Name')

total_player_dictionary
# Out:
#                     Opp  Season Team  GMS        ST        PTS        REB  \
# Name
# Russell Westbrook   Uta    2021  WAS   46  1.000000  21.717391  10.695652
# Bradley Beal        Uta    2021  WAS   45  0.977778  30.311111   4.733333
# Deandre Ayton        1.452830  1.150943  0.490566  ...   32.91
# Dejounte Murray      5.220000  0.100000  1.600000  ...   36.48
# DeMar DeRozan        7.088889  0.244444  0.911111  ...   37.23
# Jakob Poeltl         1.884615  1.615385  0.634615  ...   30.82
# Derrick White        3.250000  1.035714  0.785714  ...   29.07
# Dennis Schroder      5.340000  0.220000  1.180000  ...   32.07
# Montrezl Harrell     1.074074  0.777778  0.703704  ...   22.32
# Kyle Kuzma           1.627451  0.588235  0.431373  ...   27.43
# Andre Drummond       2.379310  1.103448  1.517241  ...   26.97
# Wendell Carter Jr.   2.097561  0.829268  0.658537  ...   27.78
# Cole Anthony         3.931034  0.448276  0.655172  ...   24.12
# Terrence Ross        2.318182  0.454545  1.022727  ...   27.27
#
#                                 Full Name  Abr  Fantasy Data Abbr  2020-2021  \
# Name
# Russell Westbrook               Utah Jazz  Uta                UTA      107.6
# Bradley Beal                    Utah Jazz  Uta                UTA      107.6
# Stephen Curry              Denver Nuggets  Den                DEN      111.7
# Andrew Wiggins             Denver Nuggets  Den                DEN      111.7
# Draymond Green             Denver Nuggets  Den                DEN      111.7
# Zion Williamson          Sacramento Kings  Sac                SAC      117.8
# Brandon Ingram           Sacramento Kings  Sac                SAC      117.8
# James Johnson            Sacramento Kings  Sac                SAC      117.8
# Nikola Vucevic          Memphis Grizzlies  Mem                MEM      110.0
# Zach LaVine             Memphis Grizzlies  Mem                MEM      110.0
# Thaddeus Young          Memphis Grizzlies  Mem                MEM      110.0
# Tomas Satoransky        Memphis Grizzlies  Mem                MEM      110.0
# Nikola Jokic        Golden State Warriors  GSW                 GS      110.4
# Jamal Murray        Golden State Warriors  GSW                 GS      110.4
# Michael Porter Jr.  Golden State Warriors  GSW                 GS      110.4
# Luka Doncic            Philadelphia 76ers  Phi                PHI      106.4
# De'Aaron Fox         New Orleans Pelicans  Nor                 NO      115.0
# Richaun Holmes       New Orleans Pelicans  Nor                 NO      115.0
# Harrison Barnes      New Orleans Pelicans  Nor                 NO      115.0
# Tyrese Haliburton    New Orleans Pelicans  Nor                 NO      115.0
# Donovan Mitchell       Washington Wizards  Was                WAS      113.3
# Rudy Gobert            Washington Wizards  Was                WAS      113.3
# Joel Embiid              Dallas Mavericks  Dal                DAL      111.7
# Tobias Harris            Dallas Mavericks  Dal                DAL      111.7
# Ben Simmons              Dallas Mavericks  Dal                DAL      111.7
# Julius Randle          Los Angeles Lakers  LAL                LAL      105.6
# RJ Barrett             Los Angeles Lakers  LAL                LAL      105.6
# John Wall                    Phoenix Suns  Pho                PHO      108.6
# Kelly Olynyk                 Phoenix Suns  Pho                PHO      108.6
# Christian Wood               Phoenix Suns  Pho                PHO      108.6
# Kevin Porter Jr.             Phoenix Suns  Pho                PHO      108.6
# Jae'sean Tate                Phoenix Suns  Pho                PHO      108.6
# Jonas Valanciunas           Chicago Bulls  Chi                CHI      112.3
# Ja Morant                   Chicago Bulls  Chi                CHI      112.3
# Kyle Anderson               Chicago Bulls  Chi                CHI      112.3
# Grayson Allen               Chicago Bulls  Chi                CHI      112.3
# Devin Booker              Houston Rockets  Hou                HOU      112.6
# Chris Paul                Houston Rockets  Hou                HOU      112.6
# Deandre Ayton             Houston Rockets  Hou                HOU      112.6
# Dejounte Murray             Orlando Magic  Orl                ORL      112.7
# DeMar DeRozan               Orlando Magic  Orl                ORL      112.7
# Jakob Poeltl                Orlando Magic  Orl                ORL      112.7
# Derrick White               Orlando Magic  Orl                ORL      112.7
# Dennis Schroder           New York Knicks  NYK                 NY      107.4
# Montrezl Harrell          New York Knicks  NYK                 NY      107.4
# Kyle Kuzma                New York Knicks  NYK                 NY      107.4
# Andre Drummond            New York Knicks  NYK                 NY      107.4
# Wendell Carter Jr.      San Antonio Spurs  SAS                 SA      111.0
# Cole Anthony            San Antonio Spurs  SAS                 SA      111.0
# Terrence Ross           San Antonio Spurs  SAS                 SA      111.0
#
#                     2019-2020  2018-2019  OPP  10_FGM     10_FGA
# Name
# Russell Westbrook       109.3      105.3  UTA     8.6  18.574514
# Bradley Beal            109.3      105.3  UTA     8.6  19.413093
# Stephen Curry           110.4      108.1  DEN    11.0  21.235521
# Andrew Wiggins          110.4      108.1  DEN     7.6  15.478615
# Draymond Green          110.4      108.1  DEN     3.1   7.692308
# Zion Williamson         111.4      110.8  SAC    11.8  18.849840
# Brandon Ingram          111.4      110.8  SAC     8.6  19.239374
# James Johnson           111.4      110.8  SAC     3.2   7.223476
# Nikola Vucevic          109.7      108.0  MEM     8.9  17.519685
# Zach LaVine             109.7      108.0  MEM     8.6  20.427553
# Thaddeus Young          109.7      108.0  MEM     5.7  10.344828
# Tomas Satoransky        109.7      108.0  MEM     3.6   7.422680
# Nikola Jokic            113.0      108.6   GS     9.2  17.100372
# Jamal Murray            113.0      108.6   GS     8.7  17.647059
# Michael Porter Jr.      113.0      108.6   GS     8.8  15.658363
# Luka Doncic             108.4      109.0  PHI    10.0  19.920319
# De'Aaron Fox            111.8      112.0   NO    10.4  21.311475
# Richaun Holmes          111.8      112.0   NO     5.8  10.265487
# Harrison Barnes         111.8      112.0   NO     4.8  10.389610
# Tyrese Haliburton       111.8      112.0   NO     5.4  11.563169
# Donovan Mitchell        114.7      112.9  WAS    10.3  21.413721
# Rudy Gobert             114.7      112.9  WAS     5.0   6.337136
# Joel Embiid             111.2      110.1  DAL     9.0  17.751479
# Tobias Harris           111.2      110.1  DAL     7.6  13.768116
# Ben Simmons             111.2      110.1  DAL     3.5   7.760532
# Julius Randle           106.1      108.9  LAL     7.7  18.734793
# RJ Barrett              106.1      108.9  LAL     6.1  12.951168
# John Wall               110.8      114.2  PHO     6.9  19.113573
# Kelly Olynyk            110.8      114.2  PHO     6.2  10.402685
# Christian Wood          110.8      114.2  PHO     7.1  15.301724
# Kevin Porter Jr.        110.8      114.2  PHO     5.8  13.302752
# Jae'sean Tate           110.8      114.2  PHO     5.2  10.505051
# Jonas Valanciunas       108.9      112.8  CHI     9.3  14.176829
# Ja Morant               108.9      112.8  CHI     5.9  12.882096
# Kyle Anderson           108.9      112.8  CHI     4.4  10.068650
# Grayson Allen           108.9      112.8  CHI     4.2   8.695652
# Devin Booker            109.8      110.1  HOU    10.0  21.276596
# Chris Paul              109.8      110.1  HOU     5.7  11.491935
# Deandre Ayton           109.8      110.1  HOU     7.1  10.872894
# Dejounte Murray         109.2      107.6  ORL     7.6  16.000000
# DeMar DeRozan           109.2      107.6  ORL     8.2  16.141732
# Jakob Poeltl            109.2      107.6  ORL     5.3   7.782673
# Derrick White           109.2      107.6  ORL     6.3  14.516129
# Dennis Schroder         112.4      112.9   NY     5.7  12.954545
# Montrezl Harrell        112.4      112.9   NY     4.2   9.312639
# Kyle Kuzma              112.4      112.9   NY     6.0  15.915119
# Andre Drummond          112.4      112.9   NY     5.1  11.538462
# Wendell Carter Jr.      112.6      110.6   SA     5.0   8.445946
# Cole Anthony            112.6      110.6   SA     4.5  11.166253
# Terrence Ross           112.6      110.6   SA     6.1  14.698795
#
# [50 rows x 48 columns]

# %% [markdown]
# ### Collect the columns of data needed by the linear regression model

# %%
Top_50_X = total_player_dictionary.loc[:,['10FPTS', '10PTS', '10AST', '10STL', '10BLK', '10DD2', '10TD3', 'MIN', '10_FGA', '2020-2021']]

Top_50_X
# Out:
#                     10FPTS  10PTS  10AST  10STL  10BLK  10DD2  10TD3  \
# Name
# Russell Westbrook    56.10   22.5   13.0    0.9    0.3    1.0    0.9
# Bradley Beal         31.66   23.4    5.0    0.3    0.1    0.0    0.0
# Stephen Curry        47.90   34.6    4.8    1.1    0.1    0.1    0.0
# Andrew Wiggins       33.80   19.6    3.2    1.1    1.2    0.1    0.0
# Draymond Green       30.00    8.2    7.6    2.2    0.7    0.2    0.0
# Zion Williamson      48.24   31.7    4.4    1.0    0.6    0.2    0.0
# Brandon Ingram       37.20   25.0    5.0    0.8    0.4    0.0    0.0
# James Johnson        19.93    8.8    2.7    1.0    1.2    0.0    0.0
# Nikola Vucevic       41.61   21.8    3.5    1.1    1.0    0.5    0.0
# Zach LaVine          37.42   24.2    5.6    0.3    0.6    0.1    0.0
# Thaddeus Young       27.39   13.4    4.1    0.5    0.6    0.1    0.0
# Tomas Satoransky     21.85    8.8    6.1    1.3    0.1    0.1    0.0
# Nikola Jokic         48.63   22.7    9.9    0.9    0.7    0.8    0.2
# Jamal Murray         37.08   23.0    5.2    1.8    0.2    0.1    0.0
# Michael Porter Jr.   35.95   21.8    1.5    0.4    0.8    0.6    0.0
# Luka Doncic          42.10   27.0    6.2    0.8    0.5    0.0    0.0
# De'Aaron Fox         44.97   29.0    6.3    1.7    0.7    0.0    0.0
# Richaun Holmes       31.59   14.6    1.1    0.5    1.9    0.5    0.0
# Harrison Barnes      28.15   13.4    2.9    1.2    0.3    0.3    0.0
# Tyrese Haliburton    24.55   13.1    5.1    0.9    0.4    0.2    0.0
# Donovan Mitchell     41.64   30.2    4.4    0.9    0.3    0.0    0.0
# Rudy Gobert          37.53   13.5    1.7    0.8    2.4    0.7    0.0
# Tyrese Haliburton   30.333333  11.563169      115.0
# Donovan Mitchell    33.666667  21.413721      113.3
# Rudy Gobert         30.925926   6.337136      113.3
# Joel Embiid         32.083333  17.751479      111.7
# Tobias Harris       33.250000  13.768116      111.7
# Ben Simmons         33.152174   7.760532      111.7
# Julius Randle       37.037037  18.734793      105.6
# RJ Barrett          33.963636  12.951168      105.6
# John Wall           32.114286  19.113573      108.6
# Kelly Olynyk        27.415094  10.402685      108.6
# Christian Wood      31.774194  15.301724      108.6
# Kevin Porter Jr.    31.058824  13.302752      108.6
# Jae'sean Tate       28.722222  10.505051      108.6
# Jonas Valanciunas   27.893617  14.176829      112.3
# Ja Morant           31.795455  12.882096      112.3
# Kyle Anderson       27.280000  10.068650      112.3
# Grayson Allen       24.743590   8.695652      112.3
# Devin Booker        34.000000  21.276596      112.6
# Chris Paul          31.730769  11.491935      112.6
# Deandre Ayton       30.603774  10.872894      112.6
# Dejounte Murray     31.640000  16.000000      112.7
# DeMar DeRozan       33.822222  16.141732      112.7
# Jakob Poeltl        25.942308   7.782673      112.7
# Derrick White       29.285714  14.516129      112.7
# Dennis Schroder     31.700000  12.954545      107.4
# Montrezl Harrell    24.444444   9.312639      107.4
# Kyle Kuzma          28.039216  15.915119      107.4
# Andre Drummond      27.931034  11.538462      107.4
# Wendell Carter Jr.  25.268293   8.445946      111.0
# Cole Anthony        26.413793  11.166253      111.0
# Terrence Ross       29.386364  14.698795      111.0

# %% [markdown]
# ### Make Predictions using the model

# %%
Top_50_predictions = Top_50_Model.predict(Top_50_X)
Top_50_X['FPTS_Pred'] = Top_50_predictions
Top_50_X
# Out:
#                     10FPTS  10PTS  10AST  10STL  10BLK  10DD2  10TD3  \
# Name
# Russell Westbrook    56.10   22.5   13.0    0.9    0.3    1.0    0.9
# Bradley Beal         31.66   23.4    5.0    0.3    0.1    0.0    0.0
# Stephen Curry        47.90   34.6    4.8    1.1    0.1    0.1    0.0
# Andrew Wiggins       33.80   19.6    3.2    1.1    1.2    0.1    0.0
# Draymond Green       30.00    8.2    7.6    2.2    0.7    0.2    0.0
# Zion Williamson      48.24   31.7    4.4    1.0    0.6    0.2    0.0
# Brandon Ingram       37.20   25.0    5.0    0.8    0.4    0.0    0.0
# James Johnson        19.93    8.8    2.7    1.0    1.2    0.0    0.0
# Nikola Vucevic       41.61   21.8    3.5    1.1    1.0    0.5    0.0
# Zach LaVine          37.42   24.2    5.6    0.3    0.6    0.1    0.0
# Thaddeus Young       27.39   13.4    4.1    0.5    0.6    0.1    0.0
# Tomas Satoransky     21.85    8.8    6.1    1.3    0.1    0.1    0.0
# Nikola Jokic         48.63   22.7    9.9    0.9    0.7    0.8    0.2
# Jamal Murray         37.08   23.0    5.2    1.8    0.2    0.1    0.0
# Michael Porter Jr.   35.95   21.8    1.5    0.4    0.8    0.6    0.0
# Luka Doncic          42.10   27.0    6.2    0.8    0.5    0.0    0.0
# De'Aaron Fox         44.97   29.0    6.3    1.7    0.7    0.0    0.0
# Zach LaVine         35.134615  20.427553      110.0  36.495193
# Thaddeus Young      24.857143  10.344828      110.0  25.557218
# Tomas Satoransky    23.809524   7.422680      110.0  24.171488
# Nikola Jokic        35.407407  17.100372      110.4  50.441495
# Jamal Murray        35.479167  17.647059      110.4  37.166265
# Michael Porter Jr.  30.522727  15.658363      110.4  36.272652
# Luka Doncic         35.020833  19.920319      106.4  37.766681
# De'Aaron Fox        34.943396  21.311475      115.0  41.428976
# Richaun Holmes      29.960000  10.265487      115.0  26.370287
# Harrison Barnes     36.176471  10.389610      115.0  30.674955
# Tyrese Haliburton   30.333333  11.563169      115.0  27.973493
# Donovan Mitchell    33.666667  21.413721      113.3  39.756091
# Rudy Gobert         30.925926   6.337136      113.3  27.914760
# Joel Embiid         32.083333  17.751479      111.7  37.080466
# Tobias Harris       33.250000  13.768116      111.7  29.516963
# Ben Simmons         33.152174   7.760532      111.7  26.480767
# Julius Randle       37.037037  18.734793      105.6  43.173349
# RJ Barrett          33.963636  12.951168      105.6  24.751175
# John Wall           32.114286  19.113573      108.6  38.561560
# Kelly Olynyk        27.415094  10.402685      108.6  28.953732
# Christian Wood      31.774194  15.301724      108.6  34.512320
# Kevin Porter Jr.    31.058824  13.302752      108.6  31.720025
# Jae'sean Tate       28.722222  10.505051      108.6  22.978758
# Jonas Valanciunas   27.893617  14.176829      112.3  42.875614
# Ja Morant           31.795455  12.882096      112.3  31.531526
# Kyle Anderson       27.280000  10.068650      112.3  26.096614
# Grayson Allen       24.743590   8.695652      112.3  21.288860
# Devin Booker        34.000000  21.276596      112.6  38.170210
# Chris Paul          31.730769  11.491935      112.6  39.266187
# Deandre Ayton       30.603774  10.872894      112.6  32.314120
# Dejounte Murray     31.640000  16.000000      112.7  36.985340
# DeMar DeRozan       33.822222  16.141732      112.7  37.662391
# Jakob Poeltl        25.942308   7.782673      112.7  25.764474
# Derrick White       29.285714  14.516129      112.7  26.297341
# Dennis Schroder     31.700000  12.954545      107.4  32.281237
# Montrezl Harrell    24.444444   9.312639      107.4  21.049875
# Kyle Kuzma          28.039216  15.915119      107.4  28.116051
# Andre Drummond      27.931034  11.538462      107.4  28.703151
# Wendell Carter Jr.  25.268293   8.445946      111.0  23.639675
# Cole Anthony        26.413793  11.166253      111.0  24.591188
# Terrence Ross       29.386364  14.698795      111.0  27.316453

# %% [markdown]
# ## Remove the Top 50 Players so we are left with the remaining players for the simpler model

# %%
# Create List of the Top 50 players from the total_player_dictionary dataframe

total_player_dictionary = pd.read_csv('player_data_csv.csv')

Top_50_list = list(total_player_dictionary['Name'])

mask_50 = (DK_Data['Name'].isin(Top_50_list))
mask_not_50 = (~DK_Data['Name'].isin(Top_50_list))

DK_Data['Top_50'] = (DK_Data['Name'].isin(Top_50_list))

Rest_of_Players_list = list(mask_not_50*DK_Data['Name'])

Rest_of_Players_list

Rest_of_Players_list = [i for i in Rest_of_Players_list if i]

Rest_of_Players_list
# Out:
# ['Rui Hachimura',
#  'Deni Avdija',
#  'Thomas Bryant',
#  'Davis Bertans',
#  'Raul Neto',
#  'Alex Len',
#  'Ish Smith',
#  'Robin Lopez',
#  'Daniel Gafford',
#  'Isaac Bonga',
#  'Anthony Gill',
#  'Chandler Hutchison',
#  'Garrison Mathews',
#  'Cassius Winston',
#  'Kristaps Porzingis',
#  'Dorian Finney-Smith',
#  'Tim Hardaway Jr.',
#  'Josh Richardson',
#  'Jalen Brunson',
#  'Maxi Kleber',
#  'Boban Marjanovic',
#  'Nicolo Melli',
#  'Dwight Powell',
#  'JJ Redick',
#  'Trey Burke',
#  'Tyler Bey',
#  'Josh Green',
#  'Nate Hinton',
#  'Willie Cauley-Stein',
#  'Tyrell Terry',
#  'James Harden',
#  'Kyrie Irving',
#  'Kevin Durant',
#  'Joe Harris',
#  'LaMarcus Aldridge',
#  'Bruce Brown',
#  'Jeff Green',
#  'Blake Griffin',
#  'DeAndre Jordan',
#  'Landry Shamet',
#  'Alize Johnson',
#  'Timothe Luwawu-Cabarrot',
#  'Nicolas Claxton',
#  'Tyler Johnson',
#  'Spencer Dinwiddie',
#  'Chris Chiozza',
#  'Reggie Perry',
#  'Karl-Anthony Towns',
#  'Anthony Edwards',
#  "D'Angelo Russell",
#  'Malik Beasley',
#  'Ricky Rubio',
#  'Jaden McDaniels',
#  'Jaylen Nowell',
#  'Jordan McLaughlin',
#  'Naz Reid',
#  'Josh Okogie',
#  'Jarrett Culver',
#  'Juancho Hernangomez',
#  'Jake Layman',
#  'Ed Davis',
#  'Jarred Vanderbilt',
#  'Seth Curry',
#  'Dwight Howard',
#  'Danny Green',
#  'Shake Milton',
#  'Furkan Korkmaz',
#  'George Hill',
#  'Matisse Thybulle',
#  'Tyrese Maxey',
#  'Mike Scott',
#  'Rayjon Tucker',
#  'Paul Reed',
#  'Isaiah Joe',
#  'Mason Jones',
#  'Mike Conley',
#  'Joe Ingles',
#  'Jordan Clarkson',
#  'Bojan Bogdanovic',
#  "Royce O'Neale",
#  'Derrick Favors',
#  'Georges Niang',
#  'Ersan Ilyasova',
#  'Matt Thomas',
#  'Jarrell Brantley',
#  'Juwan Morgan',
#  'Trent Forrest',
#  'Udoka Azubuike',
#  'Elijah Hughes',
#  'Miye Oni',
#  'Coby White',
#  'Patrick Williams',
#  'Lauri Markkanen',
#  'Al-Farouq Aminu',
#  'Daniel Theis',
#  'Adam Mokoka',
#  'Denzel Valentine',
#  'Garrett Temple',
#  'Javonte Green',
#  'Ryan Arcidiacono',
#  'Cristiano Felicio',
#  'Troy Brown Jr.',
#  'Devon Dotson',
#  'Mikal Bridges',
#  'Jae Crowder',
#  'Cameron Payne',
#  'Cameron Johnson',
#  'Dario Saric',
#  'Torrey Craig',
#  'Jevon Carter',
#  "E'Twaun Moore",
#  'Langston Galloway',
#  'Frank Kaminsky',
#  'Abdel Nader',
#  'Ty-Shon Alexander',
#  'Jalen Smith',
#  "Jae'Sean Tate",
#  'Eric Gordon',
#  'Danuel House Jr.',
#  'Sterling Brown',
#  'D.J. Augustin',
#  'Avery Bradley',
#  'KJ Martin Jr.',
#  'David Nwaba',
#  'Dante Exum',
#  'D.J. Wilson',
#  'DaQuan Jeffries',
#  'Armoni Brooks',
#  'Anthony Lamb',
#  'Keldon Johnson',
#  'Rudy Gay',
#  'Lonnie Walker IV',
#  'Patty Mills',
#  'Cameron Reynolds',
#  'Drew Eubanks',
#  'Luka Samanic',
#  'Devin Vassell',
#  'Gorgui Dieng',
#  'Keita Bates-Diop',
#  'Trey Lyles',
#  'Quinndary Weatherspoon',
#  'Tre Jones',
#  'Jaren Jackson Jr.',
#  'Dillon Brooks',
#  "De'Anthony Melton",
#  'Brandon Clarke',
#  'Desmond Bane',
#  'Justise Winslow',
#  'Xavier Tillman',
#  'Tyus Jones',
#  'Jontay Porter',
#  'John Konchar',
#  'Sean McDermott',
#  'Killian Tillie',
#  'James Ennis III',
#  'Chuma Okeke',
#  'Dwayne Bacon',
#  'Otto Porter Jr.',
#  'Michael Carter-Williams',
#  'Mo Bamba',
#  'R.J. Hampton',
#  'Chasson Randle',
#  'Gary Harris',
#  'Devin Cannady',
#  'Karim Mane',
#  'Jonathan Isaac',
#  'Markelle Fultz']

# %%
# Use that list to only keep the players not in the Top 50 performers

DK_Data = DK_Data.set_index('Name')

Rest_of_Players = DK_Data.loc[Rest_of_Players_list]

Rest_of_Players
# Out:
#                Position                  Name + ID        ID Roster Position  \
# Name
# Rui Hachimura        PF   Rui Hachimura (17028596)  17028596       PF/F/UTIL
# Deni Avdija       SF/PF     Deni Avdija (17028719)  17028719    SF/PF/F/UTIL
# Thomas Bryant         C   Thomas Bryant (17028760)  17028760          C/UTIL
# Davis Bertans     SF/PF   Davis Bertans (17028863)  17028863    SF/PF/F/UTIL
# Raul Neto         PG/SG       Raul Neto (17028884)  17028884    PG/SG/G/UTIL
# ...                 ...                        ...       ...             ...
# Gary Harris       SG/SF     Gary Harris (17028917)  17028917  SG/SF/F/G/UTIL
# Devin Cannady        PG   Devin Cannady (17028979)  17028979       PG/G/UTIL
# Karim Mane           PG      Karim Mane (17029065)  17029065       PG/G/UTIL
# Jonathan Isaac       PF  Jonathan Isaac (17029196)  17029196       PF/F/UTIL
# Markelle Fultz       PG  Markelle Fultz (17029199)  17029199       PG/G/UTIL
#
#                 Salary                      Game Info TeamAbbrev  \
# Name
# Rui Hachimura     6300  WAS@UTA 04/12/2021 09:00PM ET        WAS
# Deni Avdija       5000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# Thomas Bryant     4600  WAS@UTA 04/12/2021 09:00PM ET        WAS
# Davis Bertans     4100  WAS@UTA 04/12/2021 09:00PM ET        WAS
# Raul Neto         4000  WAS@UTA 04/12/2021 09:00PM ET        WAS
# ...                ...                            ...        ...
# Gary Harris       3900   SA@ORL 04/12/2021 08:00PM ET        ORL
# Devin Cannady     3500   SA@ORL 04/12/2021 08:00PM ET        ORL
# Karim Mane        3200   SA@ORL 04/12/2021 08:00PM ET        ORL
# Jonathan Isaac    3000   SA@ORL 04/12/2021 08:00PM ET        ORL
# Markelle Fultz    3000   SA@ORL 04/12/2021 08:00PM ET        ORL
#
#                 AvgPointsPerGame Away Home  OPP          Full Name  Abr  \
# Name
# Rui Hachimura              25.29  WAS  UTA  UTA          Utah Jazz  Uta
# Deni Avdija                16.47  WAS  UTA  UTA          Utah Jazz  Uta
# Thomas Bryant              26.62  WAS  UTA  UTA          Utah Jazz  Uta
# Davis Bertans              18.88  WAS  UTA  UTA          Utah Jazz  Uta
# Raul Neto                  16.74  WAS  UTA  UTA          Utah Jazz  Uta
# ...                          ...  ...  ...  ...                ...  ...
# Gary Harris                17.43   SA  ORL   SA  San Antonio Spurs  SAS
# Devin Cannady               4.00   SA  ORL   SA  San Antonio Spurs  SAS
# Karim Mane                  3.94   SA  ORL   SA  San Antonio Spurs  SAS
# Jonathan Isaac              0.00   SA  ORL   SA  San Antonio Spurs  SAS
# Markelle Fultz             26.66   SA  ORL   SA  San Antonio Spurs  SAS
#
#                Fantasy Data Abbr  2020-2021  2019-2020  2018-2019  Top_50
# Name
# Rui Hachimura                UTA      107.6      109.3      105.3   False
# Deni Avdija                  UTA      107.6      109.3      105.3   False
# Thomas Bryant                UTA      107.6      109.3      105.3   False
# Davis Bertans                UTA      107.6      109.3      105.3   False
# Raul Neto                    UTA      107.6      109.3      105.3   False
# ...                          ...        ...        ...        ...     ...
# Gary Harris                   SA      111.0      112.6      110.6   False
# Devin Cannady                 SA      111.0      112.6      110.6   False
# Karim Mane                    SA      111.0      112.6      110.6   False
# Jonathan Isaac                SA      111.0      112.6      110.6   False
# Markelle Fultz                SA      111.0      112.6      110.6   False
#
# [167 rows x 18 columns]

# %% [markdown]
# ## Predict FPTS for Rest of Players Cohort

# %%
R_o_P_X = Rest_of_Players.loc[:,['AvgPointsPerGame', '2020-2021']]

R_o_P_X
# Out:
#                 AvgPointsPerGame  2020-2021
# Name
# Rui Hachimura              25.29      107.6
# Deni Avdija                16.47      107.6
# Thomas Bryant              26.62      107.6
# Davis Bertans              18.88      107.6
# Raul Neto                  16.74      107.6
# ...                          ...        ...
# Gary Harris                17.43      111.0
# Devin Cannady               4.00      111.0
# Karim Mane                  3.94      111.0
# Jonathan Isaac              0.00      111.0
# Markelle Fultz             26.66      111.0
#
# [167 rows x 2 columns]

# %%
Rest_of_Players_predictions = Rest_of_Players_Model.predict(R_o_P_X)
R_o_P_X['FPTS_Pred'] = Rest_of_Players_predictions
R_o_P_X
# Out:
#                 AvgPointsPerGame  2020-2021  FPTS_Pred
# Name
# Rui Hachimura              25.29      107.6  25.470518
# Deni Avdija                16.47      107.6  17.455069
# Thomas Bryant              26.62      107.6  26.679197
# Davis Bertans              18.88      107.6  19.645231
# Raul Neto                  16.74      107.6  17.700440
# ...                          ...        ...        ...
# Gary Harris                17.43      111.0  19.123648
# Devin Cannady               4.00      111.0   6.918718
# Karim Mane                  3.94      111.0   6.864191
# Jonathan Isaac              0.00      111.0   3.283593
# Markelle Fultz             26.66      111.0  27.511698
#
# [167 rows x 3 columns]
